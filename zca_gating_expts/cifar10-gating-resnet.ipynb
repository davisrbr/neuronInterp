# %%
import ctypes
libgcc_s = ctypes.CDLL('libgcc_s.so.1')
import torch
#torch.manual_seed(0)
from torchvision import datasets, transforms

from projections import LayerModifierZCA
from notebook_train import run_train_test_loop, test
from gating_resnet import resnet18_sigmoid, resnet18_fixed

# %% [markdown]
# # Mode 0 i.e. equivalent to Gated Linear Units = Sigmoid$(w_1^Tx)*(w_2^Tx)$, both $w_1, w_2$ are learnable, works as well as ReLUs.

# %%
# for now, no augmentations



device = torch.device("cuda")


mean = (0.5070751592371323, 0.48654887331495095, 0.4409178433670343)
std = (0.2673342858792401, 0.2564384629170883, 0.27615047132568404)

transform_train = transforms.Compose([
    #transforms.ToPILImage(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])


dataset1 = datasets.CIFAR10('../data', train=True, download=True,
                   transform=transform_train)
dataset2 = datasets.CIFAR10('../data', train=False,
                   transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)


model = resnet18_sigmoid(mode=0).to(device)
# Out:
# Files already downloaded and verified

# %%
# from torchinfo import summary

# for module in model.modules():
#     # print(module)
#     if isinstance(module, torch.nn.BatchNorm2d):
#         if hasattr(module, 'weight'):
#             module.weight.requires_grad_(True)
#         if hasattr(module, 'bias'):
#             module.bias.requires_grad_(True)
#     else:
#         if hasattr(module, 'weight'):
#             module.weight.requires_grad_(False)
#         if hasattr(module, 'bias'):
#             try:
#                 module.bias.requires_grad_(False)
#             except:
#                 pass
# summary(model)

# %%
# retrain = True
# if retrain:
#     run_train_test_loop(model, train_loader, test_loader, "cifar_100_res_g0_batch", epochs=1, device=device)    

# #print('c')

# %%
from torchinfo import summary

# for module in model.modules():
#     # print(module)
#     if isinstance(module, torch.nn.BatchNorm2d):
#         if hasattr(module, 'weight'):
#             module.weight.requires_grad_(False)
#         if hasattr(module, 'bias'):
#             module.bias.requires_grad_(False)
#     else:
#         if hasattr(module, 'weight'):
#             module.weight.requires_grad_(True)
#         if hasattr(module, 'bias'):
#             try:
#                 module.bias.requires_grad_(True)
#             except:
#                 pass
summary(model)
# Out:
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ResNetSigmoid                                 --
# ├─ConvSigmoidNorm: 1-1                        --
# │    └─Conv2d: 2-1                            9,408
# │    └─Conv2d: 2-2                            9,408
# ├─BatchNorm2d: 1-2                            128
# ├─MaxPool2d: 1-3                              --
# ├─Sequential: 1-4                             --
# │    └─BasicBlockSigmoidGating: 2-3           --
# │    │    └─ConvSigmoidNorm: 3-1              73,728
# │    │    └─BatchNorm2d: 3-2                  128
# │    │    └─BatchNorm2d: 3-3                  128
# │    │    └─ConvSigmoidNormResidual: 3-4      73,728
# │    └─BasicBlockSigmoidGating: 2-4           --
# │    │    └─ConvSigmoidNorm: 3-5              73,728
# │    │    └─BatchNorm2d: 3-6                  128
# │    │    └─BatchNorm2d: 3-7                  128
# │    │    └─ConvSigmoidNormResidual: 3-8      73,728
# ├─Sequential: 1-5                             --
# │    └─BasicBlockSigmoidGating: 2-5           --
# │    │    └─ConvSigmoidNorm: 3-9              147,456
# │    │    └─BatchNorm2d: 3-10                 256
# │    │    └─BatchNorm2d: 3-11                 256
# │    │    └─Sequential: 3-12                  8,448
# │    │    └─ConvSigmoidNormResidual: 3-13     294,912
# │    └─BasicBlockSigmoidGating: 2-6           --
# │    │    └─ConvSigmoidNorm: 3-14             294,912
# │    │    └─BatchNorm2d: 3-15                 256
# │    │    └─BatchNorm2d: 3-16                 256
# │    │    └─ConvSigmoidNormResidual: 3-17     294,912
# ├─Sequential: 1-6                             --
# │    └─BasicBlockSigmoidGating: 2-7           --
# │    │    └─ConvSigmoidNorm: 3-18             589,824
# │    │    └─BatchNorm2d: 3-19                 512
# │    │    └─BatchNorm2d: 3-20                 512
# │    │    └─Sequential: 3-21                  33,280
# │    │    └─ConvSigmoidNormResidual: 3-22     1,179,648
# │    └─BasicBlockSigmoidGating: 2-8           --
# │    │    └─ConvSigmoidNorm: 3-23             1,179,648
# │    │    └─BatchNorm2d: 3-24                 512
# │    │    └─BatchNorm2d: 3-25                 512
# │    │    └─ConvSigmoidNormResidual: 3-26     1,179,648
# ├─Sequential: 1-7                             --
# │    └─BasicBlockSigmoidGating: 2-9           --
# │    │    └─ConvSigmoidNorm: 3-27             2,359,296
# │    │    └─BatchNorm2d: 3-28                 1,024
# │    │    └─BatchNorm2d: 3-29                 1,024
# │    │    └─Sequential: 3-30                  132,096
# │    │    └─ConvSigmoidNormResidual: 3-31     4,718,592
# │    └─BasicBlockSigmoidGating: 2-10          --
# │    │    └─ConvSigmoidNorm: 3-32             4,718,592
# │    │    └─BatchNorm2d: 3-33                 1,024
# │    │    └─BatchNorm2d: 3-34                 1,024
# │    │    └─ConvSigmoidNormResidual: 3-35     4,718,592
# ├─AdaptiveAvgPool2d: 1-8                      --
# ├─Linear: 1-9                                 51,300
# ======================================================================
# Total params: 22,222,692
# Trainable params: 22,222,692
# Non-trainable params: 0
# ======================================================================

# %%
run_train_test_loop(
    model, 
    train_loader, 
    test_loader, 
    "cifar_10_res_g0_full",
    epochs=90, 
    device=device
)
# Out:
# best acc: 85.16

# %%
model = resnet18_fixed(mode=0).to(device)    
summary(model)
# Out:
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ResNetFixed                                   --
# ├─ConvTwoStreamNorm: 1-1                      --
# │    └─Conv2d: 2-1                            9,408
# │    └─Conv2d: 2-2                            (9,408)
# ├─BatchNorm2d: 1-2                            128
# ├─MaxPool2d: 1-3                              --
# ├─Sequential: 1-4                             --
# │    └─BasicBlockFixed: 2-3                   --
# │    │    └─ConvTwoStreamNorm: 3-1            73,728
# │    │    └─BatchNorm2d: 3-2                  128
# │    │    └─BatchNorm2d: 3-3                  128
# │    │    └─ConvTwoStreamResidual: 3-4        73,728
# │    └─BasicBlockFixed: 2-4                   --
# │    │    └─ConvTwoStreamNorm: 3-5            73,728
# │    │    └─BatchNorm2d: 3-6                  128
# │    │    └─BatchNorm2d: 3-7                  128
# │    │    └─ConvTwoStreamResidual: 3-8        73,728
# ├─Sequential: 1-5                             --
# │    └─BasicBlockFixed: 2-5                   --
# │    │    └─ConvTwoStreamNorm: 3-9            147,456
# │    │    └─BatchNorm2d: 3-10                 256
# │    │    └─BatchNorm2d: 3-11                 256
# │    │    └─Sequential: 3-12                  8,448
# │    │    └─ConvTwoStreamResidual: 3-13       294,912
# │    └─BasicBlockFixed: 2-6                   --
# │    │    └─ConvTwoStreamNorm: 3-14           294,912
# │    │    └─BatchNorm2d: 3-15                 256
# │    │    └─BatchNorm2d: 3-16                 256
# │    │    └─ConvTwoStreamResidual: 3-17       294,912
# ├─Sequential: 1-6                             --
# │    └─BasicBlockFixed: 2-7                   --
# │    │    └─ConvTwoStreamNorm: 3-18           589,824
# │    │    └─BatchNorm2d: 3-19                 512
# │    │    └─BatchNorm2d: 3-20                 512
# │    │    └─Sequential: 3-21                  33,280
# │    │    └─ConvTwoStreamResidual: 3-22       1,179,648
# │    └─BasicBlockFixed: 2-8                   --
# │    │    └─ConvTwoStreamNorm: 3-23           1,179,648
# │    │    └─BatchNorm2d: 3-24                 512
# │    │    └─BatchNorm2d: 3-25                 512
# │    │    └─ConvTwoStreamResidual: 3-26       1,179,648
# ├─Sequential: 1-7                             --
# │    └─BasicBlockFixed: 2-9                   --
# │    │    └─ConvTwoStreamNorm: 3-27           2,359,296
# │    │    └─BatchNorm2d: 3-28                 1,024
# │    │    └─BatchNorm2d: 3-29                 1,024
# │    │    └─Sequential: 3-30                  132,096
# │    │    └─ConvTwoStreamResidual: 3-31       4,718,592
# │    └─BasicBlockFixed: 2-10                  --
# │    │    └─ConvTwoStreamNorm: 3-32           4,718,592
# │    │    └─BatchNorm2d: 3-33                 1,024
# │    │    └─BatchNorm2d: 3-34                 1,024
# │    │    └─ConvTwoStreamResidual: 3-35       4,718,592
# ├─AdaptiveAvgPool2d: 1-8                      --
# ├─Linear: 1-9                                 51,300
# ======================================================================
# Total params: 22,222,692
# Trainable params: 11,227,812
# Non-trainable params: 10,994,880
# ======================================================================

# %%
run_train_test_loop(
    model, 
    train_loader, 
    test_loader, 
    "cifar_10_res_fixed_m0",
    epochs=90, 
    device=device
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1d52bf9306cc> in <module>
#       5     "cifar_10_res_fixed_m0",
#       6     epochs=90,
# ----> 7     device=device
#       8 )
#       9
#
# /qfs/people/brow843/neuronInterp/zca_gating_expts/notebook_train.py in run_train_test_loop(model, train_loader, test_loader, model_name, epochs, device)
#      87     for epoch in range(1, epochs + 1):
#      88         #print('mid', flush=True)
# ---> 89         train_loss, train_acc = train(model, device, train_loader, optimizer, criterion, epoch)
#      90         val_loss, val_acc = test(model, device, test_loader, criterion)
#      91         #print('b23')
#
# /qfs/people/brow843/neuronInterp/zca_gating_expts/notebook_train.py in train(model, device, train_loader, optimizer, criterion, epoch)
#      26         data, target = data.to(device), target.to(device)
#      27         optimizer.zero_grad()
# ---> 28         output = model(data)
#      29         pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
#      30         correct += pred.eq(target.view_as(pred)).sum().item()
#
# ~/miniconda3/envs/neuronInterp/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /qfs/people/brow843/neuronInterp/zca_gating_expts/gating_resnet.py in forward(self, x)
#     266
#     267     def forward(self, x):
# --> 268         return self._forward_impl(x)
#     269
#     270
#
# /qfs/people/brow843/neuronInterp/zca_gating_expts/gating_resnet.py in _forward_impl(self, x)
#     248     def _forward_impl(self, x):
#     249         # See note [TorchScript super()]
# --> 250         x, x_init = self.conv1_two_stream(x, self.bn1)
#     251         # x = self.conv1(x)
#     252         # x = self.bn1(x)
#
# ~/miniconda3/envs/neuronInterp/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /qfs/people/brow843/neuronInterp/zca_gating_expts/cifar_model.py in forward(self, x, norm_layer, x_init)
#     286         if self.mode == 0:
#     287             x_init = F.relu(self.conv_init(x_init))
# --> 288             x = F.relu(norm_layer(self.conv(x)))
#     289
#     290         if self.mode == 1 or self.mode == 2 or self.mode == 3:
#
# ~/miniconda3/envs/neuronInterp/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/neuronInterp/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     177             bn_training,
#     178             exponential_average_factor,
# --> 179             self.eps,
#     180         )
#     181
#
# ~/miniconda3/envs/neuronInterp/lib/python3.6/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2281
#    2282     return torch.batch_norm(
# -> 2283         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2284     )
#    2285
#
# KeyboardInterrupt:

# %%
dataset1 = datasets.CIFAR100('../data', train=True, download=True,
                   transform=transform_train)
dataset2 = datasets.CIFAR100('../data', train=False,
                   transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)


model = resnet18_fixed(mode=0).to(device)    
run_train_test_loop(
    model, 
    train_loader, 
    test_loader, 
    "cifar_100_res_fixed_m0",
    epochs=250, 
    device=device
)
# Out:
# best acc: 59.6

# %%
model = mCNN_k_g().cuda().eval()
state_dict = torch.load("models/cifar_10_g0.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.1548151664435864, 80.95)

# %% [markdown]
# # Mode 1 i.e. = Sigmoid$(w_1^Tx)*(w_{\text{init}}^Tx)$, only $w_1$ is learnable.

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_k_g(mode=1).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_g1", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 59.65

# %%
model = mCNN_k_g(mode=1).cuda().eval()
state_dict = torch.load("models/cifar_10_g1.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.1544224351644516, 59.65)

# %% [markdown]
# # Mode 2 i.e. = Sigmoid$(w_{\text{init}}^Tx)*(w_{2}^Tx)$, only $w_2$ is learnable.

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_k_g(mode=2).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_g2", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 77.51

# %%
model = mCNN_k_g(mode=2).cuda().eval()
state_dict = torch.load("models/cifar_10_g2.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.2180578254163266, 77.51)

# %% [markdown]
# # Mode 2 i.e. = Sigmoid$(w_{\text{init}}^Tx)*(w_{2}^Tx)$, only $w_2$ is learnable WITH 4x width

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_k_g(c = 256, mode=2).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_g2", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 83.38

# %%
model = mCNN_k_g(c = 256, mode=2).cuda().eval()
state_dict = torch.load("models/cifar_10_g2.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.2118349362164735, 83.38)

# %% [markdown]
# # Fixed Mode 0 i.e. normal neural network

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_fixed().to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_f0", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 81.22

# %%
model = mCNN_fixed().cuda().eval()
state_dict = torch.load("models/cifar_10_f0.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.2762156330049037, 81.22)

# %% [markdown]
# # Fixed Mode 1 i.e. fixing gating to init gating

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_fixed(mode = 1).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_f1", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 74.31

# %%
model = mCNN_fixed(mode = 1).cuda().eval()
state_dict = torch.load("models/cifar_10_f1.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.9789395958185196, 74.31)

# %% [markdown]
# # Fixed Mode 1 i.e. fixing gating to init gating, WITH 4x width this time

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_fixed(c = 256, mode = 1).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_f1", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 77.2

# %%
model = mCNN_fixed(c = 256, mode = 1).cuda().eval()
state_dict = torch.load("models/cifar_10_f1.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.850194238871336, 77.2)

# %% [markdown]
# # Fixed Mode 2 i.e. fixing gating to another init gating

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_fixed(mode = 2).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_f2", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 75.39

# %%
model = mCNN_fixed(mode = 2).cuda().eval()
state_dict = torch.load("models/cifar_10_f2.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.8789202347397804, 75.39)

# %% [markdown]
# # Fixed Mode 3 i.e. no learning in Conv layers, linear still learnt, just a sanity check

# %%
# for now, no augmentations



device = torch.device("cuda")

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset1 = datasets.CIFAR10('data', train=True, download=True,
                   transform=transform)
dataset2 = datasets.CIFAR10('data', train=False,
                   transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1, num_workers = 4, pin_memory = True, batch_size=125, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset2,  num_workers = 4, pin_memory = True, batch_size=125)

#print('a')

model = mCNN_fixed(mode = 3).to(device)

#print('b')    
    
retrain = True
if retrain:
    run_train_test_loop(model, train_loader, test_loader, "cifar_10_f3", epochs=50, device=device)    

#print('c')
# Out:
# best acc: 35.63

# %%
model = mCNN_fixed(mode = 3).cuda().eval()
state_dict = torch.load("models/cifar_10_f3.pt",) # map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
test(model, device, test_loader, torch.nn.CrossEntropyLoss())
# Out:
# (1.9809390038251877, 35.63)

# %%
from cifar_model import ConvTwoStream # (inplanes, planes, stride)

# %%
ConvTwoStream(3, 64, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-86c1354b02c4> in <module>
# ----> 1 ConvTwoStream(3, 64)
#
# TypeError: __init__() missing 1 required positional argument: 'kernel_size'

# %%
from torchinfo import summary


summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# mCNN_fixed                               --
# ├─ConvTwoStream: 1-1                     --
# │    └─Conv2d: 2-1                       (1,792)
# │    └─Conv2d: 2-2                       (1,792)
# ├─ConvTwoStream: 1-2                     --
# │    └─Conv2d: 2-3                       (73,728)
# │    └─Conv2d: 2-4                       (73,728)
# ├─MaxPool2d: 1-3                         --
# ├─MaxPool2d: 1-4                         --
# ├─ConvTwoStream: 1-5                     --
# │    └─Conv2d: 2-5                       (294,912)
# │    └─Conv2d: 2-6                       (294,912)
# ├─ConvTwoStream: 1-6                     --
# │    └─Conv2d: 2-7                       (1,179,648)
# │    └─Conv2d: 2-8                       (1,179,648)
# ├─Flatten: 1-7                           --
# ├─Linear: 1-8                            5,120
# =================================================================
# Total params: 3,105,280
# Trainable params: 5,120
# Non-trainable params: 3,100,160
# =================================================================
